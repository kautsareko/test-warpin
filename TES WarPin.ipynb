# %% [markdown]
# # Canceled

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
df=pd.read_csv('WP_CT_DA.csv', parse_dates=['Date'])
df.set_index('Date',inplace=True)
dfServiceA=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE A')]
dfServiceB=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE B')]
dfServiceC=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE C')]
dfServiceD=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE D')]
dfServiceE=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE E')]
dfServiceF=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE F')]
dfServiceG=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE G')]
dfServiceH=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE H')]
dfServiceI=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE I')]
dfServiceJ=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE J')]
dfServiceK=df[(df['Status of Order'] == 'Cancelled') & (df['Service'] == 'SERVICE K')]
dfCancelled_A=dfServiceA['# of Orders'].sum()
dfCancelled_B=dfServiceB['# of Orders'].sum()
dfCancelled_C=dfServiceC['# of Orders'].sum()
dfCancelled_D=dfServiceD['# of Orders'].sum()
dfCancelled_E=dfServiceE['# of Orders'].sum()
dfCancelled_F=dfServiceF['# of Orders'].sum()
dfCancelled_G=dfServiceG['# of Orders'].sum()
dfCancelled_H=dfServiceH['# of Orders'].sum()
dfCancelled_I=dfServiceI['# of Orders'].sum()
dfCancelled_J=dfServiceJ['# of Orders'].sum()
dfCancelled_K=dfServiceK['# of Orders'].sum()
dftotalcancel=dfCancelled_A+dfCancelled_B+dfCancelled_C+dfCancelled_D+dfCancelled_E+dfCancelled_F+dfCancelled_G+dfCancelled_H+dfCancelled_I+dfCancelled_J+dfCancelled_K
print('jumlah order yang dicancel sepanjang januari hingga april:' "\n sercive_A",dfCancelled_A,"\n sercive_B",dfCancelled_B,\
     "\n sercive_C",dfCancelled_C,"\n sercive_D",dfCancelled_D,\
     "\n sercive_E",dfCancelled_E,"\n sercive_F",dfCancelled_F,\
     "\n sercive_G",dfCancelled_G,"\n sercive_H",dfCancelled_H,\
     "\n sercive_I",dfCancelled_I,"\n sercive_J",dfCancelled_J,\
     "\n sercive_K",dfCancelled_K,)
print('dan total seluruh order yang memilik status cancel untuk seluruh service yaitu:',dftotalcancel)
# # dfServiceA = pd.DataFrame(dfServiceA)
# # dfServiceA.plot()
# fig, ax = plt.subplots(figsize=(15,7))
# # dfServiceA.plot(ax=ax)
# dfServiceA.plot(kind='bar', ax=ax)
# ax.plot(dfServiceA.index, dfServiceA['# of Orders'])
# Out:
# jumlah order yang dicancel sepanjang januari hingga april:
#  sercive_A 29970
#  sercive_B 1740
#  sercive_C 2033930
#  sercive_D 1270
#  sercive_E 1050
#  sercive_F 85700
#  sercive_G 7330
#  sercive_H 5469180
#  sercive_I 485160
#  sercive_J 660540
#  sercive_K 23120
# dan total seluruh order yang memilik status cancel untuk seluruh service yaitu: 8798990

# %% [markdown]
# # No Driver Found

# %%
dfServiceA_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE A')]
dfServiceB_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE B')]
dfServiceC_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE C')]
dfServiceD_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE D')]
dfServiceE_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE E')]
dfServiceF_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE F')]
dfServiceG_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE G')]
dfServiceH_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE H')]
dfServiceI_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE I')]
dfServiceJ_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE J')]
dfServiceK_NDF=df[(df['Status of Order'] == 'No Driver Found') & (df['Service'] == 'SERVICE K')]
dfNDF_A=dfServiceA_NDF['# of Orders'].sum()
dfNDF_B=dfServiceB_NDF['# of Orders'].sum()
dfNDF_C=dfServiceC_NDF['# of Orders'].sum()
dfNDF_D=dfServiceD_NDF['# of Orders'].sum()
dfNDF_E=dfServiceE_NDF['# of Orders'].sum()
dfNDF_F=dfServiceF_NDF['# of Orders'].sum()
dfNDF_G=dfServiceG_NDF['# of Orders'].sum()
dfNDF_H=dfServiceH_NDF['# of Orders'].sum()
dfNDF_I=dfServiceI_NDF['# of Orders'].sum()
dfNDF_J=dfServiceJ_NDF['# of Orders'].sum()
dfNDF_K=dfServiceK_NDF['# of Orders'].sum()
dftotal_NDF=dfNDF_A+dfNDF_B+dfNDF_C+dfNDF_D+dfNDF_E+dfNDF_F+dfNDF_G+dfNDF_H+dfNDF_I+dfNDF_J+dfNDF_K
print('jumlah order yang memiliki status No Driver Found sepanjang januari hingga april:' "\n sercive_A",dfNDF_A,"\n sercive_B",dfNDF_B,\
     "\n sercive_C",dfNDF_C,"\n sercive_D",dfNDF_D,\
     "\n sercive_E",dfNDF_E,"\n sercive_F",dfNDF_F,\
     "\n sercive_G",dfNDF_G,"\n sercive_H",dfNDF_H,\
     "\n sercive_I",dfNDF_I,"\n sercive_J",dfNDF_J,\
     "\n sercive_K",dfNDF_K,)
print('dan total seluruh order yang memilik status No Driver Found untuk seluruh service yaitu:',dftotal_NDF)
# Out:
# jumlah order yang memiliki status No Driver Found sepanjang januari hingga april:
#  sercive_A 3510
#  sercive_B 610
#  sercive_C 39260
#  sercive_D 2060
#  sercive_E 1380
#  sercive_F 410
#  sercive_G 3120
#  sercive_H 1471780
#  sercive_I 112160
#  sercive_J 27200
#  sercive_K 0
# dan total seluruh order yang memilik status No Driver Found untuk seluruh service yaitu: 1661490

# %% [markdown]
# # Other/Failed/Timeout

# %%
# dfOFT=df[df["Status of Order"]!='No Driver Found' df["Status of Order"]!='Cancelled' df["Status of Order"]!='Completed']
# dfOFT
dfServiceA_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE A')]
dfServiceB_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE B')]
dfServiceC_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE C')]
dfServiceD_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE D')]
dfServiceE_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE E')]
dfServiceF_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE F')]
dfServiceG_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE G')]
dfServiceH_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE H')]
dfServiceI_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE I')]
dfServiceJ_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE J')]
dfServiceK_OFT=df[(df['Status of Order'] .isin(['Cancelled', 'No Driver Found', 'Completed'])==False) & (df['Service'] == 'SERVICE K')]
dfOFT_A=dfServiceA_OFT['# of Orders'].sum()
dfOFT_B=dfServiceB_OFT['# of Orders'].sum()
dfOFT_C=dfServiceC_OFT['# of Orders'].sum()
dfOFT_D=dfServiceD_OFT['# of Orders'].sum()
dfOFT_E=dfServiceE_OFT['# of Orders'].sum()
dfOFT_F=dfServiceF_OFT['# of Orders'].sum()
dfOFT_G=dfServiceG_OFT['# of Orders'].sum()
dfOFT_H=dfServiceH_OFT['# of Orders'].sum()
dfOFT_I=dfServiceI_OFT['# of Orders'].sum()
dfOFT_J=dfServiceJ_OFT['# of Orders'].sum()
dfOFT_K=dfServiceK_OFT['# of Orders'].sum()
dftotal_OFT=dfOFT_A+dfOFT_B+dfOFT_C+dfOFT_D+dfOFT_E+dfOFT_F+dfOFT_G+dfOFT_H+dfOFT_I+dfOFT_J+dfOFT_K
print('jumlah order yang memiliki status Other/Failed/Timeout sepanjang januari hingga april:' "\n sercive_A",dfOFT_A,"\n sercive_B",dfOFT_B,\
     "\n sercive_C",dfOFT_C,"\n sercive_D",dfOFT_D,\
     "\n sercive_E",dfOFT_E,"\n sercive_F",dfOFT_F,\
     "\n sercive_G",dfOFT_G,"\n sercive_H",dfOFT_H,\
     "\n sercive_I",dfOFT_I,"\n sercive_J",dfOFT_J,\
     "\n sercive_K",dfOFT_K,)
print('dan total seluruh order yang memilik status Other/Failed/Timeout untuk seluruh service yaitu:',dftotal_OFT)
# Out:
# jumlah order yang memiliki status Other/Failed/Timeout sepanjang januari hingga april:
#  sercive_A 0
#  sercive_B 670
#  sercive_C 1670
#  sercive_D 40
#  sercive_E 0
#  sercive_F 0
#  sercive_G 410
#  sercive_H 5200
#  sercive_I 250
#  sercive_J 150
#  sercive_K 4370
# dan total seluruh order yang memilik status Other/Failed/Timeout untuk seluruh service yaitu: 12760

# %% [markdown]
# # Completed

# %%
dfServiceA_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE A')]
dfServiceB_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE B')]
dfServiceC_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE C')]
dfServiceD_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE D')]
dfServiceE_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE E')]
dfServiceF_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE F')]
dfServiceG_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE G')]
dfServiceH_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE H')]
dfServiceI_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE I')]
dfServiceJ_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE J')]
dfServiceK_Completed=df[(df['Status of Order'] == 'Completed') & (df['Service'] == 'SERVICE K')]
dfCompleted_A=dfServiceA_Completed['# of Orders'].sum()
dfCompleted_B=dfServiceB_Completed['# of Orders'].sum()
dfCompleted_C=dfServiceC_Completed['# of Orders'].sum()
dfCompleted_D=dfServiceD_Completed['# of Orders'].sum()
dfCompleted_E=dfServiceE_Completed['# of Orders'].sum()
dfCompleted_F=dfServiceF_Completed['# of Orders'].sum()
dfCompleted_G=dfServiceG_Completed['# of Orders'].sum()
dfCompleted_H=dfServiceH_Completed['# of Orders'].sum()
dfCompleted_I=dfServiceI_Completed['# of Orders'].sum()
dfCompleted_J=dfServiceJ_Completed['# of Orders'].sum()
dfCompleted_K=dfServiceK_Completed['# of Orders'].sum()
dftotalcompleted=dfCompleted_A+dfCompleted_B+dfCompleted_C+dfCompleted_D+dfCompleted_E+dfCompleted_F+dfCompleted_G+dfCompleted_H+dfCompleted_I+dfCompleted_J+dfCompleted_K
print('jumlah order yang memiliki status Completed sepanjang januari hingga april:' "\n sercive_A",dfCompleted_A,"\n sercive_B",dfCompleted_B,\
     "\n sercive_C",dfCompleted_C,"\n sercive_D",dfCompleted_D,\
     "\n sercive_E",dfCompleted_E,"\n sercive_F",dfCompleted_F,\
     "\n sercive_G",dfCompleted_G,"\n sercive_H",dfCompleted_H,\
     "\n sercive_I",dfCompleted_I,"\n sercive_J",dfCompleted_J,\
     "\n sercive_K",dfCompleted_K,)
print('dan total seluruh order yang memilik status Completed untuk seluruh service yaitu:',dftotalcompleted)
# Out:
# jumlah order yang memiliki status Completed sepanjang januari hingga april:
#  sercive_A 65030
#  sercive_B 14510
#  sercive_C 6715000
#  sercive_D 7630
#  sercive_E 17340
#  sercive_F 196430
#  sercive_G 42610
#  sercive_H 30726460
#  sercive_I 3107340
#  sercive_J 1365020
#  sercive_K 5970
# dan total seluruh order yang memilik status Completed untuk seluruh service yaitu: 42263340

# %% [markdown]
# # Conclusion

# %%
print('total seluruh order:',dftotalcancel+dftotal_NDF+dftotal_OFT+dftotalcompleted)
Cancelled=8798990
NoDriverFound=1661490
Other_Failed_TimeOut=16270
Completed=42263340
Total_Order=52740090
perCancel=(Cancelled/Total_Order)*100
perNoDriverFound=(NoDriverFound/Total_Order)*100
perOther_Failed_TimeOut=(Other_Failed_TimeOut/Total_Order)*100
perCompleted=(Completed/Total_Order)*100
print('persentasenya adalah:',perCancel, perNoDriverFound, perOther_Failed_TimeOut, perCompleted)


sizes = [perCancel, perCompleted, perNoDriverFound, perOther_Failed_TimeOut]
labels = ["Cancelled", "Completed", "No Driver Found", "Other/Failed/TimeOut"]

explode = (0.4, 0, 0.3, 0.5) 

fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',startangle=90,shadow=True,wedgeprops={'linewidth': 3})
ax1.axis('equal')  
plt.show()
# Out:
# total seluruh order: 52736580
# persentasenya adalah: 16.683684081691936 3.1503359209284625 0.030849397488703564 80.1351305998909

# %%
# dfServiceA = pd.DataFrame(dfServiceA)
# dfServiceA.plot()
fig, ax = plt.subplots(figsize=(15,7))
# dfServiceA.plot(ax=ax)
ax.plot(dfServiceK.index, dfServiceK['# of Orders'])

# %% [markdown]
# # Hal lain yang didapat

# %%
dfcompleted=df[df["Status of Order"]=='Completed']
dfcompleted=dfcompleted[dfcompleted['Total CBV']=='-']
dfcompleted
dfcancelled=df[df["Status of Order"]=='Cancelled']
dfcancelled=dfcancelled[dfcancelled['Total CBV']=='']
dfcancelled.shape

# terdapat 20
# Out:
# (0, 12)
